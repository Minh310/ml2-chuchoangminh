# %% [markdown]
# Ex1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
means = [2, 2]
cov = [[1, 0], [0, 1]]
N = 50
X = np.random.multivariate_normal(means, cov, N)

# %%
fig, axes = plt.subplots()
axes.scatter(X[:, 0], X[:, 1])

# %%
X = X - X.mean(axis=0)

# %%
X_std = X/ np.std(X, axis=0)
cov_mat = np.cov(X_std.T)

# %%
e, v = np.linalg.eig(cov_mat)
print('E-value:', e)
print('E-vector', v)
# Out:
# E-value: [1.13110634 0.90970999]
# E-vector [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
max_vec = v[:, e.argmax()]
print(max_vec)
# Out:
# [0.70710678 0.70710678]

# %%
dt = X_std.dot(max_vec)*max_vec[:, np.newaxis]

# %%
plt.scatter(dt[0], dt[1])

# %% [markdown]
# Ex3

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
d = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

# %%
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
x = d.loc[:, features].values

# %%
fig, axes = plt.subplots()
axes.scatter(x[:, 0], x[:, 1])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)

# %%
plt.scatter(principalComponents[:,0], principalComponents[:,1])

# %%
plt.plot(principalComponents[:,0], principalComponents[:,1], 'bo', markersize = 4, alpha = .8)
plt.axvline(x=0, ymin=0, ymax=1, lw=1.5, label='boudary', c='black')
plt.axhline(y=0, xmin=0, xmax=1, lw=1.5, c='black')
plt.show()
